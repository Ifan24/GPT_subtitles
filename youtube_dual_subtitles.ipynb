# %% [markdown]
# <a href="https://colab.research.google.com/github/Ifan24/youtube_dual_subtitles/blob/main/youtube_dual_subtitles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dual Subtitles for Video in Google Colab
#
# This notebook allows you to download a YouTube video (or use your own local video file), transcribe it, translate the transcript into a target language (Using Google API or GPT3.5!)

# %% [markdown]
# ## Setting Up

# %%
#@title Let's start by installing necessary dependencies.
# !git clone https://github.com/Ifan24/youtube_dual_subtitles.git
# !pip install -r youtube_dual_subtitles/requirements.txt

# %%
#@title Perform Google authentication (Optional)
#@markdown You can upload your local media file to Google Drive and use this script to transcribe and translate

from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Running the Script
# Now, you're ready to run the script. You can provide either a YouTube URL or a local video file for processing. The script will transcribe the video, translate the transcript, and generate dual subtitles in the form of an SRT file.
#
# Before running the script, please set the following parameters:

# %%
#@title Running the Script

#@markdown If `video_path` is a YouTube link, the video will be downloaded at the `video`.
video_path = 'https://www.youtube.com/watch?v=31oxj6mcsOM&ab_channel=TwoMinutePapers' #@param {type: 'string'}

#@markdown Choose a Whisper model.
model_type = 'large'  #@param ["base", "small", "medium", "large"]

#@markdown The language to translate to (use language code).
target_language = 'zh' #@param {type: 'string'}

#@markdown Method to use for translation.
translation_method = 'google' #@param ["google", "gpt", "whisper", "m2m100"]

if 'www.youtube.com' in video_path:
  # !python /content/youtube_dual_subtitles/main.py --youtube_url {video_path} --model {model_type} --target_language {target_language} --translation_method {translation_method}
else:
  # !python /content/youtube_dual_subtitles/main.py --local_video {video_path} --model {model_type} --target_language {target_language} --translation_method "{translation_method}"
# Out:
# /bin/bash: --model: command not found
# 2023-07-06 10:40:32.535001: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-06 10:40:33.504581: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Failed to get name. Retrying... Press Ctrl+Z to exit
# Failed to get name. Retrying... Press Ctrl+Z to exit
# Failed to get name. Retrying... Press Ctrl+Z to exit
# Failed to get name. Retrying... Press Ctrl+Z to exit
# Failed to get name. Retrying... Press Ctrl+Z to exit
# Failed to get name. Retrying... Press Ctrl+Z to exit
# Use tmp.mp4 as the video name
# Downloading video: tmp
# SRT file downloaded at: videos/tmp/[English] tmp.srt
# SRT file downloaded at: videos/tmp/[Chinese (Simplified)] tmp.srt
# Original thumbnail saved at: videos/tmp/thumbnail.jpg
# Resized thumbnail saved at: videos/tmp/thumbnail_resized.jpg
# [youtube] Extracting URL: https://www.youtube.com/watch?v=31oxj6mcsOM
# [youtube] 31oxj6mcsOM: Downloading webpage
# [youtube] 31oxj6mcsOM: Downloading ios player API JSON
# [youtube] 31oxj6mcsOM: Downloading android player API JSON
# [youtube] 31oxj6mcsOM: Downloading player 23604418
# [youtube] 31oxj6mcsOM: Downloading m3u8 information
# [info] 31oxj6mcsOM: Downloading 1 format(s): 623+140
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 48
# [download] Destination: videos/tmp/tmp.f623.mp4
# [download] 100% of  238.43MiB in 00:00:17 at 13.67MiB/s
# [download] Destination: videos/tmp/tmp.f140.m4a
# [download] 100% of    4.12MiB in 00:00:00 at 14.01MiB/s
# [Merger] Merging formats into "videos/tmp/tmp.mp4"
# Deleting original file videos/tmp/tmp.f623.mp4 (pass -k to keep)
# Deleting original file videos/tmp/tmp.f140.m4a (pass -k to keep)
# Download complete: videos/tmp/tmp.mp4
# File size: 254.48307 mb
# Downloading (…)972fe5dc/config.json: 100% 2.37k/2.37k [00:00<00:00, 15.4MB/s]
# Downloading (…)fe5dc/tokenizer.json: 100% 2.20M/2.20M [00:00<00:00, 33.7MB/s]
# Downloading (…)fe5dc/vocabulary.txt: 100% 460k/460k [00:00<00:00, 17.4MB/s]
# Downloading model.bin: 100% 484M/484M [00:03<00:00, 155MB/s]
# Transcribing audio...
# Detected language 'en' with probability 0.794434
# [0.00s -> 4.34s]  Dear Fellow Scholars, this is Two Minute Papers with Dr. Károly Zsolnai-Fehér.
# [4.62s -> 9.48s]  Today, you are going to see virtual worlds like you've never seen before.
# [9.94s -> 13.52s]  This is done with something that we call nerfs.
# [13.90s -> 15.68s]  So what are nerfs?
# [16.02s -> 22.76s]  Essentially, we grab a smartphone and a set of images go in and reality comes out.
# [23.10s -> 28.28s]  When there is a gap between the images, it can synthesize all this information and it
# [28.28s -> 29.84s]  almost looks like reality.
# [30.54s -> 31.72s]  Absolute magic!
# [32.32s -> 38.62s]  Now, many of these are neural network based techniques and take quite a while to compute.
# [39.12s -> 44.42s]  However, later Nvidia published a technique by the name Instant Nerfs.
# [44.76s -> 51.00s]  As the name says, this trains incredibly quickly and is one of the best techniques in its class.
# [51.46s -> 56.50s]  And today, these can be produced from a smartphone camera and can be generated
# [56.50s -> 58.26s]  in a matter of seconds.
# [58.68s -> 60.68s]  But there is a problem.
# [61.30s -> 62.28s]  Do you see the problem?
# [62.90s -> 65.36s]  Well, let me ask you another question.
# [65.96s -> 69.72s]  How do you spot a Fellow Scholar who watches Two Minute Papers?
# [70.20s -> 74.58s]  Well, of course, they are always looking at thin structures.
# [75.20s -> 75.60s]  Why?
# [76.12s -> 77.08s]  Well, look.
# [77.60s -> 83.18s]  So Instant Nerfs are super fast, but have trouble with thin structures.
# [83.26s -> 90.00s]  And now, hold on to your paper Fellow Scholars and let's look at how this new paper deals
# [90.00s -> 91.40s]  with the same problem.
# [92.28s -> 94.90s]  Oh my, that is outstanding.
# [95.64s -> 102.64s]  But wait, is it only better on thin structures or is it generally better than this previous technique?
# [103.20s -> 109.98s]  Yes, thin structures are still present, but the new one is significantly better in terms of quality.
# [110.58s -> 111.06s]  Wow!
# [111.06s -> 115.94s]  And this is just one here and one more paper down the line.
# [116.48s -> 117.14s]  Very impressive.
# [117.86s -> 121.18s]  Also, here is a comparison against MiP Nerf.
# [121.62s -> 122.94s]  This is real good.
# [123.28s -> 130.90s]  So, I bet the new one isn't better, especially that this previous one ran for about 20 times longer.
# [131.46s -> 132.26s]  Let's see.
# [134.60s -> 137.52s]  Whoa!
# [138.16s -> 139.40s]  Is that really possible?
# [139.40s -> 147.00s]  The new one is still better, 20 times faster and we don't even have to pay for it by giving up quality.
# [147.68s -> 149.34s]  This is still better.
# [149.84s -> 157.72s]  With this, we can now just grab a smartphone and scan a real place and make a virtual world out of it.
# [158.04s -> 163.96s]  This can be used for video games, video conferencing, animation movies, you name it.
# [164.36s -> 166.78s]  Now, not even this work is perfect.
# [166.78s -> 172.48s]  You see, specular reflections like this display are not that faithful to reality,
# [172.96s -> 177.70s]  and if we look at severely under-sampled regions, this can happen.
# [178.14s -> 183.96s]  However, just think about the fact that all this came just one more paper down the line.
# [184.30s -> 190.26s]  Now, combine this together with this amazing light transport paper that can take photos of
# [190.26s -> 196.56s]  real-world objects and create a super advanced digital material model with just the right
# [196.56s -> 198.76s]  physical parameters to replicate it.
# [199.26s -> 206.06s]  So, Nerfs can help with the geometry and light transport can help with the materials.
# [206.58s -> 212.36s]  And a potential combination of the two could create even more incredible virtual worlds
# [212.36s -> 215.30s]  and games for us in the near future.
# [215.80s -> 217.20s]  What a time to be alive!
# [217.40s -> 220.86s]  This video has been supported by weights and biases.
# [221.54s -> 227.22s]  Look at this, they have a great community forum that aims to make you the best machine
# [227.22s -> 228.76s]  learning engineer you can be.
# [229.26s -> 233.28s]  You see, I always get messages from you fellow scholars telling me
# [233.28s -> 238.54s]  that you have been inspired by the series, but don't really know where to start.
# [239.10s -> 244.00s]  And here it is, in this forum, you can share your projects, ask for advice,
# [244.12s -> 246.72s]  look for collaborators, and more.
# [247.52s -> 255.96s]  Make sure to visit wnb.me-paper-forum and say hi or just click the link in the video description.
# [256.58s -> 261.38s]  Our thanks to weights and biases for their long-standing support and for helping us
# [261.38s -> 262.76s]  make better videos for you.
# [263.06s -> 266.80s]  Thanks for watching and for your generous support, and I'll see you next time!
# word level segments is saved at videos/tmp/tmp.json
# 56it [00:00, 109757.49it/s]
# 61it [00:00, 101973.91it/s]
# subtitle is saved at videos/tmp/tmp.srt
# original subtitle is saved at videos/tmp/tmp_original.srt
# Downloading (…)lve/main/config.json: 100% 908/908 [00:00<00:00, 5.04MB/s]
# Downloading pytorch_model.bin: 100% 1.94G/1.94G [00:08<00:00, 227MB/s]
# Downloading (…)neration_config.json: 100% 233/233 [00:00<00:00, 918kB/s]
# Downloading (…)olve/main/vocab.json: 100% 3.71M/3.71M [00:00<00:00, 11.6MB/s]
# Downloading (…)tencepiece.bpe.model: 100% 2.42M/2.42M [00:00<00:00, 6.24MB/s]
# Downloading (…)okenizer_config.json: 100% 272/272 [00:00<00:00, 1.37MB/s]
# Downloading (…)cial_tokens_map.json: 100% 1.14k/1.14k [00:00<00:00, 1.70MB/s]
#   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1273: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 200 (`generation_config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# 100% 2/2 [00:20<00:00, 10.28s/it]
# ['亲爱的同学们,这是两分钟的论文与Károly Zsolnai-Fehér博士。', '今天,你会看到虚拟世界,你从未见过。', '这就是我们称之为神经的东西,所以什么是神经?基本上,', '我们抓住一个智能手机,一组图像进来,现实出来了。', '当图像之间存在差距时,', '它可以合成所有这些信息,它几乎看起来像现实。', '绝对的魔法!现在,', '其中许多是基于神经网络的技术,需要很长时间来计算。', '然而,后来Nvidia发布了一项名为即时神经的技术。', '正如名字所说,', '它跑得非常快,是其班级最好的技术之一。', '今天,', '这些可以从智能手机摄像头中产生,并且可以在物质中产生。', '上一篇:有问题吗?你看到了问题吗?', '让我问你另一个问题。', '如何找到一个观看两分钟论文的同学? 好吧,', '当然,他们总是看着薄结构。 为什么? 好吧,看看。', '所以即时神经是超快的,但与薄结构有麻烦。', '如今,', '保持你的论文 Fellow Scholars 并让我们看看这个新论文如何处理', '同樣的問題!哦,我的,這是令人驚訝的,但等,', '它只是在薄结构上更好,或者它一般比以前更好。', '技术?是的,薄结构仍然存在,', '但新一代在质量方面显著更好!Wow!', '这里只有一个,下线还有一个,非常令人印象深刻。', '此外,这里是对 MiP Nerf 的比较,这是真正的好。', '我赌新人不好,', '特别是,这个前一个跑了大约20倍,让我们看看。', 'Whoa!这是真的可能的吗?新一个仍然更好,', '20倍快,我们甚至不需要通过放弃质量来付出代价。', '这一点还好,这点,', '我们现在只能抓住智能手机,扫描一个真实的地方,创造一个虚拟世界。', '它可以用于视频游戏,视频会议,', '动画电影,你命名它. 现在,即使这个工作也不是完美的。', '像这个显示一样的光谱反射并不那么忠于现实,', '如果我们看到了严重低估的地区,这可能会发生。', '只是想想,这一切都只有一张纸在线下。', '现在,', '将此与这个令人惊叹的光运输纸相结合,可以拍摄照片', '现实世界对象,并创建一个超级先进的数字材料模型', '正确的物理参数来复制它,所以,', '神经可以帮助地质和光运输可以帮助材料。', '而潜在的两者组合可能会创造更令人难以置信的虚拟', '世界和游戏为我们在不久的将来!什么时候活着!', '这个视频是由重量和偏见支持的。', '他们有一个伟大的社区论坛,旨在让你最好的机器学习', '你可以成为工程师,你可以看到。', '我总是得到你的同事学者的信息告诉我,你被启发了。', '由系列,但真的不知道从哪里开始。', '在这个论坛上,你可以分享你的项目,请求建议,', '寻找合作伙伴,更多', '请确保参观wnb.me-paper-forum 并说再见,或者单击视频中的链接', '描述。', '我们感谢重量和偏见,为他们的长期支持和帮助。', '我们为您制作更好的视频。', '谢谢您的观看和慷慨的支持,下次我会见到您!']
# 56it [00:00, 111582.43it/s]
# Translated subtitle is saved at videos/tmp/tmp_zh.srt
# Combining subtitles...
# 112it [00:00, 164252.46it/s]
# combine translated subtitle is saved at videos/tmp/tmp_dual_sub.srt

# %%
#@title Display the contents of the original and translated subtitle files

#@markdown Path to the original subtitle file
original_subtitle_file_path = '/content/videos/tmp/tmp.srt'  #@param {type: 'string'}

#@markdown Path to the translated subtitle file
translated_subtitle_file_path = '/content/videos/tmp/tmp_zh.srt'  #@param {type: 'string'}


import pandas as pd
from IPython.display import display, HTML

# Read the subtitle files
with open(original_subtitle_file_path, 'r') as file:
    original_subtitles = [line.strip() for line in file.readlines()]

with open(translated_subtitle_file_path, 'r') as file:
    translated_subtitles = [line.strip() for line in file.readlines()]

# Create a pandas DataFrame
df = pd.DataFrame({
    'Original Subtitles': original_subtitles,
    'Translated Subtitles': translated_subtitles
})

# Display the DataFrame
display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Original Subtitles</th>
#       <th>Translated Subtitles</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>00:00:00,000 --&gt; 00:00:04,340</td>
#       <td>00:00:00,000 --&gt; 00:00:04,340</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Dear Fellow Scholars, this is Two Minute Papers with Dr. Károly Zsolnai-Fehér.</td>
#       <td>亲爱的同学们,这是两分钟的论文与Károly Zsolnai-Fehér博士。</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>00:00:04,620 --&gt; 00:00:09,480</td>
#       <td>00:00:04,620 --&gt; 00:00:09,480</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Today, you are going to see virtual worlds like you've never seen before.</td>
#       <td>今天,你会看到虚拟世界,你从未见过。</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>3</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>00:00:09,940 --&gt; 00:00:16,500</td>
#       <td>00:00:09,940 --&gt; 00:00:16,500</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>This is done with something that we call nerfs. So what are nerfs? Essentially,</td>
#       <td>这就是我们称之为神经的东西,所以什么是神经?基本上,</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>4</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>00:00:16,980 --&gt; 00:00:22,760</td>
#       <td>00:00:16,980 --&gt; 00:00:22,760</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>we grab a smartphone and a set of images go in and reality comes out.</td>
#       <td>我们抓住一个智能手机,一组图像进来,现实出来了。</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>5</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>00:00:23,100 --&gt; 00:00:25,080</td>
#       <td>00:00:23,100 --&gt; 00:00:25,080</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>When there is a gap between the images,</td>
#       <td>当图像之间存在差距时,</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>6</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>00:00:25,400 --&gt; 00:00:29,840</td>
#       <td>00:00:25,400 --&gt; 00:00:29,840</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>it can synthesize all this information and it almost looks like reality.</td>
#       <td>它可以合成所有这些信息,它几乎看起来像现实。</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>7</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>00:00:30,540 --&gt; 00:00:32,580</td>
#       <td>00:00:30,540 --&gt; 00:00:32,580</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>Absolute magic! Now,</td>
#       <td>绝对的魔法!现在,</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>8</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>00:00:32,860 --&gt; 00:00:38,620</td>
#       <td>00:00:32,860 --&gt; 00:00:38,620</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>many of these are neural network based techniques and take quite a while to compute.</td>
#       <td>其中许多是基于神经网络的技术,需要很长时间来计算。</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>9</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>00:00:39,120 --&gt; 00:00:44,420</td>
#       <td>00:00:39,120 --&gt; 00:00:44,420</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>However, later Nvidia published a technique by the name Instant Nerfs.</td>
#       <td>然而,后来Nvidia发布了一项名为即时神经的技术。</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>10</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>00:00:44,760 --&gt; 00:00:45,620</td>
#       <td>00:00:44,760 --&gt; 00:00:45,620</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>As the name says,</td>
#       <td>正如名字所说,</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>11</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>00:00:46,020 --&gt; 00:00:51,000</td>
#       <td>00:00:46,020 --&gt; 00:00:51,000</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>this trains incredibly quickly and is one of the best techniques in its class.</td>
#       <td>它跑得非常快,是其班级最好的技术之一。</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>12</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>00:00:51,460 --&gt; 00:00:52,020</td>
#       <td>00:00:51,460 --&gt; 00:00:52,020</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>And today,</td>
#       <td>今天,</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>13</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>00:00:52,300 --&gt; 00:00:57,380</td>
#       <td>00:00:52,300 --&gt; 00:00:57,380</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>these can be produced from a smartphone camera and can be generated in a matter</td>
#       <td>这些可以从智能手机摄像头中产生,并且可以在物质中产生。</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>14</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>00:00:57,380 --&gt; 00:01:03,220</td>
#       <td>00:00:57,380 --&gt; 00:01:03,220</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>of seconds. But there is a problem. Do you see the problem? Well,</td>
#       <td>上一篇:有问题吗?你看到了问题吗?</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>15</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>00:01:03,520 --&gt; 00:01:05,360</td>
#       <td>00:01:03,520 --&gt; 00:01:05,360</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>let me ask you another question.</td>
#       <td>让我问你另一个问题。</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>16</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>00:01:05,960 --&gt; 00:01:10,580</td>
#       <td>00:01:05,960 --&gt; 00:01:10,580</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>How do you spot a Fellow Scholar who watches Two Minute Papers? Well,</td>
#       <td>如何找到一个观看两分钟论文的同学? 好吧,</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>17</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>00:01:10,840 --&gt; 00:01:17,080</td>
#       <td>00:01:10,840 --&gt; 00:01:17,080</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>of course, they are always looking at thin structures. Why? Well, look.</td>
#       <td>当然,他们总是看着薄结构。 为什么? 好吧,看看。</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>18</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>00:01:17,600 --&gt; 00:01:23,180</td>
#       <td>00:01:17,600 --&gt; 00:01:23,180</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>So Instant Nerfs are super fast, but have trouble with thin structures.</td>
#       <td>所以即时神经是超快的,但与薄结构有麻烦。</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>19</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>00:01:23,260 --&gt; 00:01:24,400</td>
#       <td>00:01:23,260 --&gt; 00:01:24,400</td>
#     </tr>
#     <

# %% [markdown]
# ## Translation with GPT-3.5
#
# In case you want to use GPT-3.5 for translating subtitles, use the following commands.
#
# 🚨🚨🚨 **WARNING**: Be careful not to share notebooks that contain your OpenAI API key. If you're running this in a shared environment, clear the output and input of this cell after running to prevent exposing your key.
#
# Or you can generate a new API key for each colab session and revoke it after it was done at https://platform.openai.com/account/api-keys

# %%
#@title Setup your OpenAI API key


import os
#@markdown OpenAI API key
OPENAI_API_KEY = 'your_api_key_here'  #@param  {type: 'string'}


os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY

# %%
#@title Use the translate_gpt.py script:

#@markdown Path to the input subtitle file.
input_file_path = '/content/videos/tmp/tmp.srt'  #@param {type: 'string'}

#@markdown The number of subtitles to process in a batch.
batch_size = 40  #@param {type: 'integer'}

#@markdown The source language of the input subtitle file. (Optional, default: 'en' for English)
source_language = 'en'  #@param {type: 'string'}

#@markdown The language to translate to (use language code).
target_language = 'zh' #@param {type: 'string'}

#@markdown Additional information about the video to improve translation accuracy. (Optional)
video_info = '\u8BF7\u51C6\u786E\u7FFB\u8BD1\u5B66\u672F\u540D\u8BCD\uFF0C\u4F8B\u5982\u628Anerf\u7FFB\u8BD1\u6210\u795E\u7ECF\u8F90\u5C04\u573A'  #@param {type: 'string'}

# %cd /content/youtube_dual_subtitles/
# !python translate_gpt.py --input_file {input_file_path} --batch_size {batch_size} --target_language {target_language} --source_language {source_language} --video_info {video_info}
# Out:
# /content/youtube_dual_subtitles
# 100% 2/2 [01:06<00:00, 33.33s/it]

# %%
#@title Display the contents of the original and translated subtitle files

#@markdown Path to the original subtitle file
original_subtitle_file_path = '/content/videos/tmp/tmp.srt'  #@param {type: 'string'}

#@markdown Path to the translated subtitle file
translated_subtitle_file_path = '/content/videos/tmp/tmp_zh.srt'  #@param {type: 'string'}

#@markdown Path to the GPT translated subtitle file
gpt_translated_subtitle_file_path = '/content/videos/tmp/tmp_zh_gpt.srt'  #@param {type: 'string'}

import pandas as pd
from IPython.display import display, HTML

# Function to read and process the subtitle files
def read_subtitles(file_path):
    with open(file_path, 'r') as file:
        subtitles = [line.strip() for line in file.readlines() if line.strip()]
    return subtitles

# Read and process the subtitle files
original_subtitles = read_subtitles(original_subtitle_file_path)
translated_subtitles = read_subtitles(translated_subtitle_file_path)
gpt_translated_subtitles = read_subtitles(gpt_translated_subtitle_file_path)

# Create a pandas DataFrame
df = pd.DataFrame({
    'Original Subtitles': original_subtitles,
    'Translated Subtitles': translated_subtitles,
    'GPT Translated Subtitles': gpt_translated_subtitles,
})

# Display the DataFrame
display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Original Subtitles</th>
#       <th>Translated Subtitles</th>
#       <th>GPT Translated Subtitles</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>00:00:00,000 --&gt; 00:00:04,340</td>
#       <td>00:00:00,000 --&gt; 00:00:04,340</td>
#       <td>00:00:00,000 --&gt; 00:00:04,340</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Dear Fellow Scholars, this is Two Minute Papers with Dr. Károly Zsolnai-Fehér.</td>
#       <td>亲爱的同学们,这是两分钟的论文与Károly Zsolnai-Fehér博士。</td>
#       <td>亲爱的学术同仁们，我是Károly Zsolnai-Fehér博士，欢迎收看《两分钟论文》。</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>00:00:04,620 --&gt; 00:00:09,480</td>
#       <td>00:00:04,620 --&gt; 00:00:09,480</td>
#       <td>00:00:04,620 --&gt; 00:00:09,480</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Today, you are going to see virtual worlds like you've never seen before.</td>
#       <td>今天,你会看到虚拟世界,你从未见过。</td>
#       <td>今天，你将看到前所未见的虚拟世界。</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>3</td>
#       <td>3</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>00:00:09,940 --&gt; 00:00:16,500</td>
#       <td>00:00:09,940 --&gt; 00:00:16,500</td>
#       <td>00:00:09,940 --&gt; 00:00:16,500</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>This is done with something that we call nerfs. So what are nerfs? Essentially,</td>
#       <td>这就是我们称之为神经的东西,所以什么是神经?基本上,</td>
#       <td>这是通过我们称之为神经辐射场（nerfs）的技术实现的。那么神经辐射场是什么呢？基本上，</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>4</td>
#       <td>4</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>00:00:16,980 --&gt; 00:00:22,760</td>
#       <td>00:00:16,980 --&gt; 00:00:22,760</td>
#       <td>00:00:16,980 --&gt; 00:00:22,760</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>we grab a smartphone and a set of images go in and reality comes out.</td>
#       <td>我们抓住一个智能手机,一组图像进来,现实出来了。</td>
#       <td>我们拿起一部智能手机，输入一组图像，然后得到真实的输出。</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>5</td>
#       <td>5</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>00:00:23,100 --&gt; 00:00:25,080</td>
#       <td>00:00:23,100 --&gt; 00:00:25,080</td>
#       <td>00:00:23,100 --&gt; 00:00:25,080</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>When there is a gap between the images,</td>
#       <td>当图像之间存在差距时,</td>
#       <td>当图像之间存在间隙时，</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>6</td>
#       <td>6</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>00:00:25,400 --&gt; 00:00:29,840</td>
#       <td>00:00:25,400 --&gt; 00:00:29,840</td>
#       <td>00:00:25,400 --&gt; 00:00:29,840</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>it can synthesize all this information and it almost looks like reality.</td>
#       <td>它可以合成所有这些信息,它几乎看起来像现实。</td>
#       <td>它可以合成所有这些信息，几乎看起来像真实世界一样。</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>7</td>
#       <td>7</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>00:00:30,540 --&gt; 00:00:32,580</td>
#       <td>00:00:30,540 --&gt; 00:00:32,580</td>
#       <td>00:00:30,540 --&gt; 00:00:32,580</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Absolute magic! Now,</td>
#       <td>绝对的魔法!现在,</td>
#       <td>绝对的魔法！现在，</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>8</td>
#       <td>8</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>00:00:32,860 --&gt; 00:00:38,620</td>
#       <td>00:00:32,860 --&gt; 00:00:38,620</td>
#       <td>00:00:32,860 --&gt; 00:00:38,620</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>many of these are neural network based techniques and take quite a while to compute.</td>
#       <td>其中许多是基于神经网络的技术,需要很长时间来计算。</td>
#       <td>其中许多是基于神经网络的技术，计算时间相当长。</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>9</td>
#       <td>9</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>00:00:39,120 --&gt; 00:00:44,420</td>
#       <td>00:00:39,120 --&gt; 00:00:44,420</td>
#       <td>00:00:39,120 --&gt; 00:00:44,420</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>However, later Nvidia published a technique by the name Instant Nerfs.</td>
#       <td>然而,后来Nvidia发布了一项名为即时神经的技术。</td>
#       <td>然而，后来Nvidia发布了一种名为Instant Nerfs的技术。</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>10</td>
#       <td>10</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>00:00:44,760 --&gt; 00:00:45,620</td>
#       <td>00:00:44,760 --&gt; 00:00:45,620</td>
#       <td>00:00:44,760 --&gt; 00:00:45,620</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>As the name says,</td>
#       <td>正如名字所说,</td>
#       <td>顾名思义，</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>11</td>
#       <td>11</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>00:00:46,020 --&gt; 00:00:51,000</td>
#       <td>00:00:46,020 --&gt; 00:00:51,000</td>
#       <td>00:00:46,020 --&gt; 00:00:51,000</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>this trains incredibly quickly and is one of the best techniques in its class.</td>
#       <td>它跑得非常快,是其班级最好的技术之一。</td>
#       <td>这种技术训练速度非常快，是同类技术中最好的之一。</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>12</td>
#       <td>12</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>00:00:51,460 --&gt; 00:00:52,020</td>
#       <td>00:00:51,460 --&gt; 00:00:52,020</td>
#       <td>00:00:51,460 --&gt; 00:00:52,020</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>And today,</td>
#       <td>今天,</td>
#       <td>而今天，</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>13</td>
#       <td>13</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>00:00:52,300 --&gt; 00:00:57,380</td>
#       <td>00:00:52,300 --&gt; 00:00:57,380</td>
#       <td>00:00:52,300 --&gt; 00:00:57,380</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>these can be produced from a smartphone camera and can be generated in a matter</td>
#       <td>这些可以从智能手机摄像头中产生,并且可以在物质中产生。</td>
#       <td>这些技术可以通过智能手机摄像头生成，并且可以在短时间内生成。</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>14</td>
#       <td>14</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>00:00:57,380 --&gt; 00:01:03,220</td>
#       <td>00:00:57,380 --&gt; 00:01:03,220</td>
#       <td>00:00:57,380 --&gt; 00:01:03,220</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>of seconds. But there is a problem. Do you see the problem? Well,</td>
#       <td>上一篇:有问题吗?你看到了问题吗?</td>
#       <td>只需要几秒钟的时间。但是有一个问题。你看到问题了吗？嗯，</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>15</td>
#       <td>15</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>00:01:03,520 --&gt; 00:01:05,360</td>
#       <td>00:01:03,520 --&gt; 00:01:05,360</td>
#       <td>00:01:03,520 --&gt; 00:01:05,360</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>let me ask you another question.</td>
#       <td>让我问你另一个问题。</td>
#       <td>让我问你另一个问题。</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>16</td>
#       <td>16</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>00:01:05,960 --&gt; 00:01:10,580</td>
#       <td>00:01:05,960 --&gt; 00:01:10,580</td>
#       <td>00:01:05,960 --&gt; 00:01:10,580</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>How do you spot a Fellow Scholar who watches Two Minute Papers? Well,</td>
#       <td>如何找到一个观看两分钟论文的同学? 好吧,</td>
#       <td>你如何识别一个看《两分钟论文》的学术同仁呢？嗯，</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>17</td>
#       <td>17</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>00:01:10,840 --&gt; 00:01:17,080</td>
#       <td>00:01:10,840 --&gt; 00:01:17,080</td>
#       <td>00:01:10,840 --&gt; 00:01:17,080</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>of course, they are always looking at thin structures. Why? Well, look.</td>
#       <td>当然,他们总是看着薄结构。 为什么? 好吧,看看。</td>
#       <td>当然，他们总是在看薄薄的结构。为什么呢？嗯，看看。</td>
#     </tr>
#     <t
